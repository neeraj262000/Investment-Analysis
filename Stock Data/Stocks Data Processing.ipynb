# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
NIFTY_50 = ["ADANIGREEN.NS", "ADANIPORTS.NS", "APOLLOHOSP.NS", "ASIANPAINT.NS", "AXISBANK.NS", "BAJFINANCE.NS", "BAJAJFINSV.NS", "BEL.NS", "BHARTIARTL.NS", "BPCL.NS", "CIPLA.NS", "COALINDIA.NS", "DRREDDY.NS", "EICHERMOT.NS", "GRASIM.NS", "HCLTECH.NS", "HDFCBANK.NS", "HDFCLIFE.NS", "HEROMOTOCO.NS", "HINDALCO.NS", "HINDUNILVR.NS", "ICICIBANK.NS", "INDUSINDBK.NS", "INFY.NS", "IOC.NS", "ITC.NS", "JSWSTEEL.NS", "KOTAKBANK.NS", "LT.NS", "M&M.NS", "MARUTI.NS", "NESTLEIND.NS", "NTPC.NS", "ONGC.NS", "POWERGRID.NS", "RELIANCE.NS", "SBILIFE.NS", "SHREECEM.NS", "SUNPHARMA.NS", "TATACONSUM.NS", "TATAMOTORS.NS", "TATASTEEL.NS", "TCS.NS", "TECHM.NS", "TITAN.NS", "TRENT.NS", "ULTRACEMCO.NS", "WIPRO.NS"]

for i in NIFTY_50:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)
    
    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name
    
    globals()[variable_name] = stock_data


ADANIGREEN["Index_name"] = "NIFTY 50"
ADANIPORTS["Index_name"] = "NIFTY 50"
APOLLOHOSP["Index_name"] = "NIFTY 50"
ASIANPAINT["Index_name"] = "NIFTY 50"
AXISBANK["Index_name"] = "NIFTY 50"
BAJFINANCE["Index_name"] = "NIFTY 50"
BAJAJFINSV["Index_name"] = "NIFTY 50"
BEL["Index_name"] = "NIFTY 50"
BHARTIARTL["Index_name"] = "NIFTY 50"
BPCL["Index_name"] = "NIFTY 50"
CIPLA["Index_name"] = "NIFTY 50"
COALINDIA["Index_name"] = "NIFTY 50"
DRREDDY["Index_name"] = "NIFTY 50"
EICHERMOT["Index_name"] = "NIFTY 50"
GRASIM["Index_name"] = "NIFTY 50"
HCLTECH["Index_name"] = "NIFTY 50"
HDFCBANK["Index_name"] = "NIFTY 50"
HDFCLIFE["Index_name"] = "NIFTY 50"
HEROMOTOCO["Index_name"] = "NIFTY 50"
HINDALCO["Index_name"] = "NIFTY 50"
HINDUNILVR["Index_name"] = "NIFTY 50"
ICICIBANK["Index_name"] = "NIFTY 50"
INDUSINDBK["Index_name"] = "NIFTY 50"
INFY["Index_name"] = "NIFTY 50"
IOC["Index_name"] = "NIFTY 50"
ITC["Index_name"] = "NIFTY 50"
JSWSTEEL["Index_name"] = "NIFTY 50"
KOTAKBANK["Index_name"] = "NIFTY 50"
LT["Index_name"] = "NIFTY 50"
M_M["Index_name"] = "NIFTY 50"
MARUTI["Index_name"] = "NIFTY 50"
NESTLEIND["Index_name"] = "NIFTY 50"
NTPC["Index_name"] = "NIFTY 50"
ONGC["Index_name"] = "NIFTY 50"
POWERGRID["Index_name"] = "NIFTY 50"
RELIANCE["Index_name"] = "NIFTY 50"
SBILIFE["Index_name"] = "NIFTY 50"
SHREECEM["Index_name"] = "NIFTY 50"
SUNPHARMA["Index_name"] = "NIFTY 50"
TATACONSUM["Index_name"] = "NIFTY 50"
TATAMOTORS["Index_name"] = "NIFTY 50"
TATASTEEL["Index_name"] = "NIFTY 50"
TCS["Index_name"] = "NIFTY 50"
TECHM["Index_name"] = "NIFTY 50"
TITAN["Index_name"] = "NIFTY 50"
TRENT["Index_name"] = "NIFTY 50"
ULTRACEMCO["Index_name"] = "NIFTY 50"
WIPRO["Index_name"] = "NIFTY 50"



NIFTY_50_only = pd.concat([ADANIGREEN, ADANIPORTS, APOLLOHOSP, ASIANPAINT, AXISBANK, BAJFINANCE, BAJAJFINSV, BEL, BHARTIARTL, BPCL, CIPLA, COALINDIA, DRREDDY, EICHERMOT, GRASIM, HCLTECH, HDFCBANK, HDFCLIFE, HEROMOTOCO, HINDALCO, HINDUNILVR, ICICIBANK, INDUSINDBK, INFY, IOC, ITC, JSWSTEEL, KOTAKBANK, LT, M_M, MARUTI, NESTLEIND, NTPC, ONGC, POWERGRID, RELIANCE, SBILIFE, SHREECEM, SUNPHARMA, TATACONSUM, TATAMOTORS, TATASTEEL, TCS, TECHM, TITAN, TRENT, ULTRACEMCO, WIPRO], ignore_index=False)

NIFTY_50_only = NIFTY_50_only[['Stock'] + [col for col in NIFTY_50_only.columns if col != 'Stock']]
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
NIFTY_50_only
# Out:
# Price            Stock   Close    High     Low    Open    Volume Index_name
# Date
# 2018-06-18  ADANIGREEN   31.50   31.50   28.50   30.00   7006229   NIFTY 50
# 2018-06-19  ADANIGREEN   32.60   33.05   31.00   32.70   2895692   NIFTY 50
# 2018-06-20  ADANIGREEN   31.00   32.20   31.00   31.50   1115553   NIFTY 50
# 2018-06-21  ADANIGREEN   29.65   30.00   29.45   29.45   2854524   NIFTY 50
# 2018-06-22  ADANIGREEN   29.45   29.80   28.20   28.20   1612972   NIFTY 50
# ...                ...     ...     ...     ...     ...       ...        ...
# 2024-12-23       WIPRO  301.90  304.60  299.06  300.63   6693583   NIFTY 50
# 2024-12-24       WIPRO  299.35  303.18  296.90  301.51   8837902   NIFTY 50
# 2024-12-26       WIPRO  299.11  300.97  298.08  299.45   6516148   NIFTY 50
# 2024-12-27       WIPRO  303.08  304.84  298.76  299.25   8063921   NIFTY 50
# 2024-12-30       WIPRO  297.78  303.37  296.75  303.08  13709891   NIFTY 50
#
# [116126 rows x 7 columns]

# %%
NIFTY_BANK = ["HDFCBANK.NS", "ICICIBANK.NS", "KOTAKBANK.NS", "AXISBANK.NS", "INDUSINDBK.NS", "BANKBARODA.NS", "PNB.NS", "IDFCFIRSTB.NS", "FEDERALBNK.NS", "AUBANK.NS"]


for i in NIFTY_BANK:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name
    
    globals()[variable_name] = stock_data

HDFCBANK["Index_name"] = "NIFTY BANK"
ICICIBANK["Index_name"] = "NIFTY BANK"
KOTAKBANK["Index_name"] = "NIFTY BANK"
AXISBANK["Index_name"] = "NIFTY BANK"
INDUSINDBK["Index_name"] = "NIFTY BANK"
BANKBARODA["Index_name"] = "NIFTY BANK"
PNB["Index_name"] = "NIFTY BANK"
IDFCFIRSTB["Index_name"] = "NIFTY BANK"
FEDERALBNK["Index_name"] = "NIFTY BANK"
AUBANK["Index_name"] = "NIFTY BANK"


NIFTY_BANK_only = pd.concat([HDFCBANK, ICICIBANK, KOTAKBANK, AXISBANK, INDUSINDBK, BANKBARODA, PNB, IDFCFIRSTB, FEDERALBNK, AUBANK], ignore_index=False)

NIFTY_BANK_only = NIFTY_BANK_only[['Stock'] + [col for col in NIFTY_BANK_only.columns if col != 'Stock']]

# %%
NIFTY_BANK_only
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 NIFTY_BANK_only
#
# NameError: name 'NIFTY_BANK_only' is not defined

# %%
NIFTY_IT = ["TCS.NS", "INFY.NS", "HCLTECH.NS", "WIPRO.NS", "LTIM.NS", "TECHM.NS", "PERSISTENT.NS", "LTTS.NS", "COFORGE.NS", "MPHASIS.NS"]


for i in NIFTY_IT:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name
    
    globals()[variable_name] = stock_data
    
    
TCS["Index_name"] = "NIFTY IT"
INFY["Index_name"] = "NIFTY IT"
HCLTECH["Index_name"] = "NIFTY IT"
WIPRO["Index_name"] = "NIFTY IT"
LTIM["Index_name"] = "NIFTY IT"
TECHM["Index_name"] = "NIFTY IT"
PERSISTENT["Index_name"] = "NIFTY IT"
LTTS["Index_name"] = "NIFTY IT"
COFORGE["Index_name"] = "NIFTY IT"
MPHASIS["Index_name"] = "NIFTY IT"

NIFTY_IT_only = pd.concat([TCS, INFY, HCLTECH, WIPRO, LTIM, TECHM, PERSISTENT, LTTS, COFORGE, MPHASIS], ignore_index=False)

NIFTY_IT_only = NIFTY_IT_only[['Stock'] + [col for col in NIFTY_IT_only.columns if col != 'Stock']]

# %%
NIFTY_IT_only

# %%
NIFTY_AUTO = ["ASHOKLEY.NS", "BAJAJ-AUTO.NS", "BALKRISIND.NS", "BHARATFORG.NS", "BOSCHLTD.NS", "EICHERMOT.NS", "HEROMOTOCO.NS", "M&M.NS", "MARUTI.NS", "MRF.NS", "TATAMOTORS.NS", "TIINDIA.NS", "TVSMOTOR.NS"]


for i in NIFTY_AUTO:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name
    
    globals()[variable_name] = stock_data


ASHOKLEY["Index_name"] = "NIFTY AUTO"
BAJAJ_AUTO["Index_name"] = "NIFTY AUTO"
BALKRISIND["Index_name"] = "NIFTY AUTO"
BHARATFORG["Index_name"] = "NIFTY AUTO"
BOSCHLTD["Index_name"] = "NIFTY AUTO"
EICHERMOT["Index_name"] = "NIFTY AUTO"
HEROMOTOCO["Index_name"] = "NIFTY AUTO"
M_M["Index_name"] = "NIFTY AUTO"
MARUTI["Index_name"] = "NIFTY AUTO"
MRF["Index_name"] = "NIFTY AUTO"
TATAMOTORS["Index_name"] = "NIFTY AUTO"
TIINDIA["Index_name"] = "NIFTY AUTO"
TVSMOTOR["Index_name"] = "NIFTY AUTO"


NIFTY_AUTO_only = pd.concat([ASHOKLEY, BAJAJ_AUTO, BALKRISIND, BHARATFORG, BOSCHLTD, EICHERMOT, HEROMOTOCO, M_M, MARUTI, MRF, TATAMOTORS, TIINDIA, TVSMOTOR], ignore_index=False)

NIFTY_AUTO_only = NIFTY_AUTO_only[['Stock'] + [col for col in NIFTY_AUTO_only.columns if col != 'Stock']]

# %%
NIFTY_AUTO_only

# %%
NIFTY_FMCG = ["BRITANNIA.NS", "COLPAL.NS", "DABUR.NS", "EMAMILTD.NS", "GODREJCP.NS", "MSUMI.NS", "HINDUNILVR.NS", "ITC.NS", "MARICO.NS", "NESTLEIND.NS", "PGHH.NS", "UBL.NS", "VBL.NS"]


for i in NIFTY_FMCG:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name
    
    globals()[variable_name] = stock_data


BRITANNIA["Index_name"] = "NIFTY FMCG"
COLPAL["Index_name"] = "NIFTY FMCG"
DABUR["Index_name"] = "NIFTY FMCG"
EMAMILTD["Index_name"] = "NIFTY FMCG"
GODREJCP["Index_name"] = "NIFTY FMCG"
MSUMI["Index_name"] = "NIFTY FMCG"
HINDUNILVR["Index_name"] = "NIFTY FMCG"
ITC["Index_name"] = "NIFTY FMCG"
MARICO["Index_name"] = "NIFTY FMCG"
NESTLEIND["Index_name"] = "NIFTY FMCG"
PGHH["Index_name"] = "NIFTY FMCG"
UBL["Index_name"] = "NIFTY FMCG"
VBL["Index_name"] = "NIFTY FMCG"

NIFTY_FMCG_only = pd.concat([BRITANNIA, COLPAL, DABUR, EMAMILTD, GODREJCP, MSUMI, HINDUNILVR, ITC, MARICO, NESTLEIND, PGHH, UBL, VBL], ignore_index=False)

NIFTY_FMCG_only = NIFTY_FMCG_only[['Stock'] + [col for col in NIFTY_FMCG_only.columns if col != 'Stock']]

# %%
NIFTY_FMCG_only

# %%
NIFTY_METAL = ["ADANIENT.NS", "APLAPOLLO.NS", "COALINDIA.NS", "HINDALCO.NS", "HINDCOPPER.NS", "HINDZINC.NS", "JINDALSTEL.NS", "JSWSTEEL.NS", "NATIONALUM.NS", "NMDC.NS", "RATNAMANI.NS", "SAIL.NS", "TATASTEEL.NS", "VEDL.NS", "WELCORP.NS"]


for i in NIFTY_METAL:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name
    
    globals()[variable_name] = stock_data



ADANIENT["Index_name"] = "NIFTY METAL"
APLAPOLLO["Index_name"] = "NIFTY METAL"
COALINDIA["Index_name"] = "NIFTY METAL"
HINDALCO["Index_name"] = "NIFTY METAL"
HINDCOPPER["Index_name"] = "NIFTY METAL"
HINDZINC["Index_name"] = "NIFTY METAL"
JINDALSTEL["Index_name"] = "NIFTY METAL"
JSWSTEEL["Index_name"] = "NIFTY METAL"
NATIONALUM["Index_name"] = "NIFTY METAL"
NMDC["Index_name"] = "NIFTY METAL"
RATNAMANI["Index_name"] = "NIFTY METAL"
SAIL["Index_name"] = "NIFTY METAL"
TATASTEEL["Index_name"] = "NIFTY METAL"
VEDL["Index_name"] = "NIFTY METAL"
WELCORP["Index_name"] = "NIFTY METAL"




NIFTY_METAL_only = pd.concat([ADANIENT, APLAPOLLO, COALINDIA, HINDALCO, HINDCOPPER, HINDZINC, JINDALSTEL, JSWSTEEL, NATIONALUM, NMDC, RATNAMANI, SAIL, TATASTEEL, VEDL, WELCORP], ignore_index=False)

NIFTY_METAL_only = NIFTY_METAL_only[['Stock'] + [col for col in NIFTY_METAL_only.columns if col != 'Stock']]

# %%
NIFTY_METAL_only

# %%
NIFTY_REALTY = ["DLF.NS", "GODREJPROP.NS", "OBEROIRLTY.NS", "PHOENIXLTD.NS", "BRIGADE.NS", "PRESTIGE.NS", "SOBHA.NS", "MAHLIFE.NS", "IBREALEST.NS", "SUNTECK.NS"]


for i in NIFTY_REALTY:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name
    
    globals()[variable_name] = stock_data


DLF["Index_name"] = "NIFTY REALTY"
GODREJPROP["Index_name"] = "NIFTY REALTY"
OBEROIRLTY["Index_name"] = "NIFTY REALTY"
PHOENIXLTD["Index_name"] = "NIFTY REALTY"
BRIGADE["Index_name"] = "NIFTY REALTY"
PRESTIGE["Index_name"] = "NIFTY REALTY"
SOBHA["Index_name"] = "NIFTY REALTY"
MAHLIFE["Index_name"] = "NIFTY REALTY"
IBREALEST["Index_name"] = "NIFTY REALTY"
SUNTECK["Index_name"] = "NIFTY REALTY"

NIFTY_REALTY_only = pd.concat([DLF, GODREJPROP, OBEROIRLTY, PHOENIXLTD, BRIGADE, PRESTIGE, SOBHA, MAHLIFE, IBREALEST, SUNTECK], ignore_index=False)

NIFTY_REALTY_only = NIFTY_REALTY_only[['Stock'] + [col for col in NIFTY_REALTY_only.columns if col != 'Stock']]

# %%
NIFTY_REALTY_only

# %%
NIFTY_ENERGY = ["RELIANCE.NS", "ONGC.NS", "NTPC.NS", "POWERGRID.NS", "IOC.NS", "BPCL.NS", "GAIL.NS", "TATAPOWER.NS", "ADANIGREEN.NS", "539254.BO", "NHPC.NS", "TORNTPOWER.NS", "OIL.NS", "ATGL.NS", "JSWENERGY.NS", "CESC.NS", "NHPC.NS", "SJVN.NS", "GUJGASLTD.NS"]


for i in NIFTY_ENERGY:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)
    
    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name

    if variable_name == "539254.BO":
        variable_name = "ADANITRANS"
        stock_data["Stock"] = "ADANITRANS"
    
    globals()[variable_name] = stock_data


RELIANCE["Index_name"] = "NIFTY_ENERGY"
ONGC["Index_name"] = "NIFTY_ENERGY"
NTPC["Index_name"] = "NIFTY_ENERGY"
POWERGRID["Index_name"] = "NIFTY_ENERGY"
IOC["Index_name"] = "NIFTY_ENERGY"
BPCL["Index_name"] = "NIFTY_ENERGY"
GAIL["Index_name"] = "NIFTY_ENERGY"
TATAPOWER["Index_name"] = "NIFTY_ENERGY"
ADANIGREEN["Index_name"] = "NIFTY_ENERGY"
ADANITRANS["Index_name"] = "NIFTY_ENERGY"
NHPC["Index_name"] = "NIFTY_ENERGY"
TORNTPOWER["Index_name"] = "NIFTY_ENERGY"
OIL["Index_name"] = "NIFTY_ENERGY"
JSWENERGY["Index_name"] = "NIFTY_ENERGY"
CESC["Index_name"] = "NIFTY_ENERGY"
NHPC["Index_name"] = "NIFTY_ENERGY"
SJVN["Index_name"] = "NIFTY_ENERGY"
ATGL["Index_name"] = "NIFTY_ENERGY"
GUJGASLTD["Index_name"] = "NIFTY_ENERGY"


NIFTY_ENERGY_only = pd.concat([RELIANCE, ONGC, NTPC, POWERGRID, IOC, BPCL, GAIL, TATAPOWER, ADANIGREEN, ADANITRANS, NHPC, TORNTPOWER, OIL, JSWENERGY, CESC, NHPC, SJVN, ATGL, GUJGASLTD], ignore_index=False)

NIFTY_ENERGY_only = NIFTY_ENERGY_only[['Stock'] + [col for col in NIFTY_ENERGY_only.columns if col != 'Stock']]

# %%
NIFTY_ENERGY_only

# %%
NIFTY_MEDIA = ["SUNTV.NS", "PVRINOX.NS", "SAREGAMA.NS", "ZEEL.NS", "TIPSMUSIC.NS", "NAZARA.NS", "NETWORK18.NS", "HATHWAY.NS", "DEN.NS", "DISHTV.NS"]

for i in NIFTY_MEDIA:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name

    if variable_name == "539254.BO":
        variable_name = "ADANITRANS"
        stock_data["Stock"] = "ADANITRANS"
    
    globals()[variable_name] = stock_data


SUNTV["Index_name"] = "NIFTY_MEDIA"
PVRINOX["Index_name"] = "NIFTY_MEDIA"
SAREGAMA["Index_name"] = "NIFTY_MEDIA"
ZEEL["Index_name"] = "NIFTY_MEDIA"
TIPSMUSIC["Index_name"] = "NIFTY_MEDIA"
NAZARA["Index_name"] = "NIFTY_MEDIA"
NETWORK18["Index_name"] = "NIFTY_MEDIA"
HATHWAY["Index_name"] = "NIFTY_MEDIA"
DEN["Index_name"] = "NIFTY_MEDIA"
DISHTV["Index_name"] = "NIFTY_MEDIA"


NIFTY_MEDIA_only = pd.concat([SUNTV, PVRINOX, SAREGAMA, ZEEL, TIPSMUSIC, NAZARA, NETWORK18, HATHWAY, DEN, DISHTV], ignore_index=False)

NIFTY_MEDIA_only = NIFTY_MEDIA_only[['Stock'] + [col for col in NIFTY_MEDIA_only.columns if col != 'Stock']]

# %%
NIFTY_MEDIA_only

# %%
NIFTY_PSU_BANK = ["BANKBARODA.NS", "PNB.NS", "CANBK.NS", "UNIONBANK.NS", "INDIANB.NS", "BANKINDIA.NS", "MAHABANK.NS", "CENTRALBK.NS", "UCOBANK.NS", "IOB.NS", "IDBI.NS"]

for i in NIFTY_PSU_BANK:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name

    if variable_name == "539254.BO":
        variable_name = "ADANITRANS"
        stock_data["Stock"] = "ADANITRANS"
    
    globals()[variable_name] = stock_data




BANKBARODA["Index_name"] = "NIFTY PSU BANK"
PNB["Index_name"] = "NIFTY PSU BANK"
CANBK["Index_name"] = "NIFTY PSU BANK"
UNIONBANK["Index_name"] = "NIFTY PSU BANK"
INDIANB["Index_name"] = "NIFTY PSU BANK"
BANKINDIA["Index_name"] = "NIFTY PSU BANK"
MAHABANK["Index_name"] = "NIFTY PSU BANK"
CENTRALBK["Index_name"] = "NIFTY PSU BANK"
UCOBANK["Index_name"] = "NIFTY PSU BANK"
IOB["Index_name"] = "NIFTY PSU BANK"
IDBI["Index_name"] = "NIFTY PSU BANK"





NIFTY_PSU_BANK_only = pd.concat([BANKBARODA, PNB, CANBK, UNIONBANK, INDIANB, BANKINDIA, MAHABANK, CENTRALBK, UCOBANK, IOB, IDBI], ignore_index=False)

NIFTY_PSU_BANK_only = NIFTY_PSU_BANK_only[['Stock'] + [col for col in NIFTY_PSU_BANK_only.columns if col != 'Stock']]

# %%
NIFTY_PSU_BANK_only

# %%
SENSEX = ["RELIANCE.NS", "HDFCBANK.NS", "INFY.NS", "ICICIBANK.NS", "TCS.NS", "KOTAKBANK.NS", "HINDUNILVR.NS", "ITC.NS", "SBIN.NS", "AXISBANK.NS", "BAJFINANCE.NS", "BHARTIARTL.NS", "ASIANPAINT.NS", "HCLTECH.NS", "MARUTI.NS", "SUNPHARMA.NS", "LT.NS", "ULTRACEMCO.NS", "NESTLEIND.NS", "TITAN.NS", "BAJAJFINSV.NS", "M&M.NS", "POWERGRID.NS", "TECHM.NS", "INDUSINDBK.NS", "NTPC.NS", "TATASTEEL.NS", "ONGC.NS", "JSWSTEEL.NS", "ADANIPORTS.NS"]

for i in SENSEX:
    stock_data = yf.download(i, start='2015-01-01', end='2024-12-31')
    
    variable_name = i.replace('.NS', '').replace('&', '_').replace('-', '_')

    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.droplevel(1)

    stock_data['Open'] = stock_data['Open'].round(2)
    stock_data['High'] = stock_data['High'].round(2)
    stock_data['Low'] = stock_data['Low'].round(2)
    stock_data['Close'] = stock_data['Close'].round(2)

    stock_data["Stock"] = variable_name

    globals()[variable_name] = stock_data

RELIANCE["Index_name"] = "SENSEX"
HDFCBANK["Index_name"] = "SENSEX"
INFY["Index_name"] = "SENSEX"
ICICIBANK["Index_name"] = "SENSEX"
TCS["Index_name"] = "SENSEX"
KOTAKBANK["Index_name"] = "SENSEX"
HINDUNILVR["Index_name"] = "SENSEX"
ITC["Index_name"] = "SENSEX"
SBIN["Index_name"] = "SENSEX"
AXISBANK["Index_name"] = "SENSEX"
BAJFINANCE["Index_name"] = "SENSEX"
BHARTIARTL["Index_name"] = "SENSEX"
ASIANPAINT["Index_name"] = "SENSEX"
HCLTECH["Index_name"] = "SENSEX"
MARUTI["Index_name"] = "SENSEX"
SUNPHARMA["Index_name"] = "SENSEX"
LT["Index_name"] = "SENSEX"
ULTRACEMCO["Index_name"] = "SENSEX"
NESTLEIND["Index_name"] = "SENSEX"
TITAN["Index_name"] = "SENSEX"
BAJAJFINSV["Index_name"] = "SENSEX"
M_M["Index_name"] = "SENSEX"
POWERGRID["Index_name"] = "SENSEX"
TECHM["Index_name"] = "SENSEX"
INDUSINDBK["Index_name"] = "SENSEX"
NTPC["Index_name"] = "SENSEX"
TATASTEEL["Index_name"] = "SENSEX"
ONGC["Index_name"] = "SENSEX"
JSWSTEEL["Index_name"] = "SENSEX"
ADANIPORTS["Index_name"] = "SENSEX"


SENSEX_only = pd.concat([RELIANCE, HDFCBANK, INFY, ICICIBANK, TCS, KOTAKBANK, HINDUNILVR, ITC, SBIN, AXISBANK, BAJFINANCE, BHARTIARTL, ASIANPAINT, HCLTECH, MARUTI, SUNPHARMA, LT, ULTRACEMCO, NESTLEIND, TITAN, BAJAJFINSV, M_M, POWERGRID, TECHM, INDUSINDBK, NTPC, TATASTEEL, ONGC, JSWSTEEL, ADANIPORTS], ignore_index=False)

SENSEX_only = SENSEX_only[['Stock'] + [col for col in SENSEX_only.columns if col != 'Stock']]

# %%
SENSEX_only

# %%
Stock_Data = pd.concat([NIFTY_50_only, NIFTY_BANK_only, NIFTY_IT_only, NIFTY_AUTO_only, NIFTY_FMCG_only, NIFTY_METAL_only, NIFTY_REALTY_only, NIFTY_ENERGY_only, NIFTY_MEDIA_only, NIFTY_PSU_BANK_only,SENSEX_only])

# %%
#Change in Price Percentage
Stock_Data['Change_Percentage_Stock'] = Stock_Data['Close'].pct_change() * 100
Stock_Data['Change_Percentage_Stock'] = Stock_Data['Change_Percentage_Stock'].round(2)

#Daily Return Percentage
Stock_Data['Daily_Return_%'] = ((Stock_Data['Close'] - Stock_Data['Open']) / Stock_Data['Open']) * 100
Stock_Data['Daily_Return_%'] = Stock_Data['Daily_Return_%'].round(2)

#Volatility
Stock_Data['Volatility'] = ((Stock_Data['High'] - Stock_Data['Low']) / Stock_Data['Open']) * 100
Stock_Data['Volatility'] = Stock_Data['Volatility'].round(2)

# %%
Stock_Data

# %%
Stock_Data.to_csv('Stock_Data.csv', index=True)

# %% [markdown]
# #Calculating Dividends

# %%
L_S_D_array = Stock_Data["Stock"].unique()
L_S_D = L_S_D_array.tolist()

# %%
L_S_D.value_counts()

# %%
start_date = "2015-01-01"
end_date = "2024-12-31"

# %%
# Download dividends within the time range

for i in L_S_D:
    var = i+ '.NS'

    dividends = yf.Ticker(var).history(start=start_date, end=end_date).get('Dividends', pd.Series())

    
    
    if not dividends.empty:
        dividends_df = dividends.reset_index()
    

    dividends_df.columns = ['Date', 'Dividends']
    
    dividends_df['Date'] = pd.to_datetime(dividends_df['Date']).dt.date
    
    dividends_df = dividends_df[dividends_df["Dividends"] != 0]
    dividends_df['Dividends'] = dividends_df['Dividends'].round(2)



    variable_name = i.replace('.NS', '') + '_div'

    globals()[variable_name] = dividends_df

# %%
RELIANCE_div
